# %% [markdown]
# # Step 1: Setting environment variables
#
# Click on the cell below, and press Shift+Enter (or press the '►' button above) to initalize the input box.
#
# Input the values into the boxes:
#
# `BASE_URL`: Base URL of the repository; e.g., "https://demo.borealisdata.ca/"
#
# `API_KEY`: Found in your Dataverse account settings. Leave blank if you don't want to input the API_KEY.

# %%
# Click here and press Shift+Enter to run this code
import dvmeta.cloud_cli as cloud_cli

cloud_cli.display_env_input()
# Out:
# Text(value='', description='BASE_URL:', placeholder='Enter the Base URL')
# Password(description='API_KEY:', placeholder='Enter your API Key')
# Button(description='Save .env', style=ButtonStyle())

# %% [markdown]
# # Step 2: Running the command line tool
#
# The following cell runs the comand line tool.
#
# **Configuration**:
#
# 1. Replace the COLLECTION_ALIAS with your desired value. See [here](https://github.com/scholarsportal/dataverse-metadata-crawler/wiki/Guide:-How-to-find-the-COLLECTION_ALIAS-of-a-Dataverse-collection) for getting your collection alias.
# 2. Replace the VERSION with your desired value. It can either be 'latest', 'latest-published' or a version number 'x.y' (like '1.0')
# 3. Add the optional flags. See the following table for your reference:
#
# **Subcommands:**
#
# | **Command**          | **Description**                                                                              |
# | -------------------- | -------------------------------------------------------------------------------------------- |
# | `search`             | Search for datasets in the collection.                                                       |
# | `crawl-metadata`     | Crawl and export dataset metadata to JSON.                                                   |
# | `crawl-permission`   | Crawl and export dataset permission metadata to JSON.                                        |
# | `export-spreadsheet` | Export crawled metadata to CSV only (No JSON).                                               |
# | `run-all`            | Run all steps in sequence (search → crawl metadata → crawl permission → export spreadsheet). |
#
# **Required options:**
#
# | **Option**         | **Short** | **Type** | **Description**                                                                                                                                                                                                                                                                                                                     | **Default**     |
# | ------------------ | --------- | -------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | --------------- |
# | --collection_alias | -c        | TEXT     | The alias of the collection to crawl. <br/> See the guide [here](https://github.com/scholarsportal/dataverse-metadata-crawler/wiki/Guide:-How-to-find-the-COLLECTION_ALIAS-of-a-Dataverse-collection) to learn how to find the collection alias. <br/> **[required]**                                                               | None            |
# | --version          | -v        | TEXT     | The dataset version to crawl. Options include: <br/> • `draft` - The draft version, if any <br/> • `latest` - Either a draft (if exists) or the latest published version <br/> • `latest-published` - The latest published version <br/> • `x.y` - A specific version (e.g. `1.0`) <br/> • `x` - Same as `x.0` <br/> **[required]** | None (required) |
#
# **Optional options:**
#
# | **Option**             | **Short** | **Type** | **Description**                                                                                                                                                                                              | **Default** |
# | ---------------------- | --------- | -------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | ----------- |
# | --auth                 | -a        | TEXT     | Authentication token to access the Dataverse repository. Can also be set via the `API_KEY` environment variable.                                                                                             | None        |
# | --report / --no-report | -r        |          | Output summary report file of the crawl.                                                                                                                                                                     | `--report`  |
# | --spreadsheet          | -s        |          | Output a CSV file of the metadata of datasets. See the [spreadsheet column explanation notes](https://github.com/scholarsportal/dataverse-metadata-crawler/wiki/Explanation-of--Spreadsheet-Column-Headers). | False       |
# | --metadata-source      | -m        | TEXT     | Filter results by metadata source. Useful for filtering harvested datasets. Note: In Borealis, it should be specified as `Borealis`                                                                          | None        |
# | --publication-status   | -ps       | TEXT     | Filter datasets by publication status (e.g. `Published`, `Draft`, `Unpublished`, `Deaccessioned`). Available values depend on the Dataverse installation.                                                    | None        |
# | --semaphore-limit      | -sl       | INT      | Maximum number of concurrent tasks when crawling datasets. Adjust based on expected load on the Dataverse repository.                                                                                        | 5           |
# | --debug-log            | -debug    |          | Enable debug logging to a file in the `logs` directory.                                                                                                                                                      | False       |
# | --log-level            |           | TEXT     | Logging level for console and file output. Options: `DEBUG`, `INFO`, `WARNING`, `ERROR`, `CRITICAL`.                                                                                                         | `INFO`      |
# | --help                 |           |          | Show the help message.                                                                                                                                                                                       |             |
#
# Example:
#
# 1. Export the metadata of latest version of datasets under collection 'demo' to JSON
#
#    `!python3 dvmeta/main.py -c demo -v latest -d`
#
# 2. Export the metadata of version 1.0 of all datasets under collection 'demo' to JSON and CSV
#
#    `!python3 dvmeta/main.py -c demo -v 1.0 -d -s`
#
# 3. Export the metadata and permission metadata of version latest-published of all datasets under collection 'toronto' to JSON and CSV. Also export the empty dataverses and datasets failed to be crawled
#
#    `!python3 dvmeta/main.py -c toronto -v latest-published -d -s -p -e -f`

# %%
# Run the command line interface
# Replace 'COLLECTION_ALIAS' and 'VERSION' with your values
# Modify the flags as needed referring to the table above
# The command below will export the dataset and permission metadata into a JSON file, plus the CSV file.
# !python3 -m dvmeta.cli.app -c 'COLLECTION_ALIAS' -v 'VERSION' run-all
# Out:
# [2026-06-08 16:39:54] - Checking the connection to the Dataverse repository...
# [2026-06-08 16:39:54] - Connection to the dataverse repository https://demo.borealisdata.ca/ with API Token is successful.
# [2026-06-08 16:39:54] - Search for datasets in collection "toronto" completed.
# Found 316 datasets.
# ⠦
# [2026-06-08 16:40:04] - Dataset metadata crawl for collection "toronto"
# completed. Crawled 316 datasets.
# ⠼
# [2026-06-08 16:40:08] - Permission metadata for collection "toronto" completed.
# Crawled 316 records.
# ⠸
# [2026-06-08 16:40:08] - Exported ds_metadata to json file: exported_files/json_files/ds_metadata_20260608-164008.json
# Checksum (SHA-256): 83b044737f0db84ffc4ea3c2b1137d58521663ace40ca9784d7e493d18c2106e
# [2026-06-08 16:40:08] - Exported Dataset Metadata CSV:
# exported_files/csv_files/ds_metadata_20260608-164008.csv
# Checksum (SHA-256):
# 2023dabe1c736da8be796b9d6e3851dc520b57379456a250882322717ab231db
# ⠋
# ...
